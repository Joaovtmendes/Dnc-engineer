# %% [markdown]
# <a href="https://colab.research.google.com/github/Joaovtmendes/Dnc-engineer/blob/main/classifica%C3%A7%C3%A3o_decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_excel("vendas.xlsx")
dados.head()
# Out:
#    media_rating  media_pedidos test cliente_comprou
# 0           1.5             11   No             Yes
# 1           2.5             11   No              No
# 2           2.5             11   No              No
# 3           1.5             13   No             Yes
# 4           2.5             13   No              No

# %%
x = dados[["media_rating","media_pedidos","test"]]
y = dados[["cliente_comprou"]]

x = pd.get_dummies(x).astype(float)
x.head()
# Out:
#    media_rating  media_pedidos  test_No  test_Yes
# 0           1.5           11.0      1.0       0.0
# 1           2.5           11.0      1.0       0.0
# 2           2.5           11.0      1.0       0.0
# 3           1.5           13.0      1.0       0.0
# 4           2.5           13.0      1.0       0.0

# %%
from sklearn import tree
arvore = tree.DecisionTreeClassifier()
modelo = arvore.fit(x,y)
modelo
# Out:
# DecisionTreeClassifier()

# %%
fig = plt.figure(figsize = (40,20))
tree = tree.plot_tree(modelo,
                      feature_names = ["yes","no"],
                      filled = True)
